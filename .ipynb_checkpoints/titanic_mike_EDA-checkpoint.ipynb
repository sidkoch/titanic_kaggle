# %% [markdown]
# # titanic with EDA & Complex slicing -- uis cs570 mike
#
# here we do eda with pandas.
#
# what to learn about each data variable.
#
# - is it numerical/categorical
# - what are min max avg
# - what are the categories
# - are there missing values
# - how is the distribution
# - how vars relate to each other
# - multi collinearity is a problem
#
#
# functions callable on a dataframe/series -->
# <ol>
#     <li> describe
#     <li> value_counts
#     <li> plot
#     <li> isnull
#     <li> hist
# </ol>

# %%
import pandas as pd
#to avoid opening visualisations in new window
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
# only shows stats for continuous variables
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# to find the percentage of ppl that survived.
survival = df.Survived.value_counts()
print(survival)
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
(342/891.0)*100
# Out:
# 38.38383838383838

# %%
# doing EDA on sex series

df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
# pandas uses matplotlib for visualisation
df.Sex.value_counts().plot(kind="bar")

# %%
# slicing the dataframe--info about all females
df[df.Sex=="female"]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 14            15         0       3
# 15            16         1       2
# 18            19         0       3
# 19            20         1       3
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 38            39         0       3
# 39            40         1       3
# 40            41         0       3
# 41            42         0       2
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 49            50         0       3
# ...

# %%
# to find if there are missing values in Sex column
df[df.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
# now checking another variable

df.Fare.value_counts()
# Out:
# 8.0500      43
# 13.0000     42
# 7.8958      38
# 7.7500      34
# 26.0000     31
# 10.5000     24
# 7.9250      18
# 7.7750      16
# 26.5500     15
# 0.0000      15
# 7.2292      15
# 7.8542      13
# 8.6625      13
# 7.2500      13
# 7.2250      12
# 16.1000      9
# 9.5000       9
# 24.1500      8
# 15.5000      8
# 56.4958      7
# 52.0000      7
# 14.5000      7
# 14.4542      7
# 69.5500      7
# 7.0500       7
# 31.2750      7
# 46.9000      6
# 30.0000      6
# 7.7958       6
# 39.6875      6
#             ..
# 7.1417       1
# 42.4000      1
# 211.5000     1
# 12.2750      1
# 61.1750      1
# 8.4333       1
# 51.4792      1
# 7.8875       1
# 8.6833       1
# 7.5208       1
# 34.6542      1
# 28.7125      1
# 25.5875      1
# 7.7292       1
# 12.2875      1
# 8.6542       1
# 8.7125       1
# 61.3792      1
# 6.9500       1
# 9.8417       1
# 8.3000       1
# 13.7917      1
# 9.4750       1
# 13.4167      1
# 26.3875      1
# 8.4583       1
# 9.8375       1
# ...

# %%
# this is a continuous variable so lets find its distribution by creating histogram
df.Fare.hist(bins=15)

# %%
# to find if there are missing values in Fare column
df[df.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
# there are a few passengers who did not pay fare
df[df.Fare==0]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
# passengers who did not pay fare but luckily survived
a = (df.Fare==0)
b = (df.Survived==1)

df[a&b]
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 271          272         1       3  Tornquist, Mr. William Henry  male  25.0
#
#      SibSp  Parch Ticket  Fare Cabin Embarked
# 271      0      0   LINE   0.0   NaN        S

# %%
# now checking another variable

df.Cabin.value_counts()
# Out:
# G6                 4
# C23 C25 C27        4
# B96 B98            4
# C22 C26            3
# D                  3
# E101               3
# F2                 3
# F33                3
# C2                 2
# E8                 2
# C78                2
# C93                2
# F4                 2
# E121               2
# B51 B53 B55        2
# D33                2
# B35                2
# E33                2
# D20                2
# E44                2
# C68                2
# B5                 2
# E25                2
# E24                2
# C83                2
# F G73              2
# D35                2
# B58 B60            2
# B57 B59 B63 B66    2
# B28                2
#                   ..
# C106               1
# C70                1
# E50                1
# C82                1
# D37                1
# B78                1
# E36                1
# D47                1
# B79                1
# B82 B84            1
# D9                 1
# D6                 1
# ...

# %%
# missing
df[df.Cabin.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# ...

# %%
# are there multicollinear variables???

# how is male survival - horizontal bar
plt.figure()
df[df.Sex=="male"].Survived.value_counts().plot(kind="barh",title="MALE SURVIVAL ON TITANIC")

# this shows how women and children were put on lifeline first
plt.figure()
df[df.Sex=="female"].Survived.value_counts().plot(kind="barh",title="FEMALE SURVIVAL ON TITANIC",)

plt.figure()
df[df.Age<5].Survived.value_counts().plot(kind="barh",title="CHILDREN SURVIVAL ON TITANIC")
